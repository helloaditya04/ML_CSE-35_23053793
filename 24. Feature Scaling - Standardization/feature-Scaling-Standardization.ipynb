# %% [markdown]
# # 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Reading a local CSV file

# %%
df = pd.read_csv('Social_Network_Ads.csv')
df = df.iloc[:,2:]
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %% [markdown]
# # 3. Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop('Purchased',axis=1), df['Purchased'], test_size=0.2, random_state=0)

# %%
X_train, X_test
# Out:
# (     Age  EstimatedSalary
#  336   58           144000
#  64    59            83000
#  55    24            55000
#  106   26            35000
#  300   58            38000
#  ..   ...              ...
#  323   48            30000
#  192   29            43000
#  117   36            52000
#  47    27            54000
#  172   26           118000
#
#  [320 rows x 2 columns],
#       Age  EstimatedSalary
#  132   30            87000
#  309   38            50000
#  341   35            75000
#  196   30            79000
#  246   35            50000
#  ..   ...              ...
#  14    18            82000
#  363   42            79000
#  304   40            60000
#  361   53            34000
#  329   47           107000
#
#  [80 rows x 2 columns])

# %% [markdown]
# # 4. Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# fit the scaler to the train dataset, it will learn the parameters
scaler.fit(X_train)

# transform the train and test sets
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[ 1.92295008e+00,  2.14601566e+00],
#        [ 2.02016082e+00,  3.78719297e-01],
#        [-1.38221530e+00, -4.32498705e-01],
#        [-1.18779381e+00, -1.01194013e+00],
#        [ 1.92295008e+00, -9.25023920e-01],
#        [ 3.67578135e-01,  2.91803083e-01],
#        [ 1.73156642e-01,  1.46942725e-01],
#        [ 2.02016082e+00,  1.74040666e+00],
#        [ 7.56421121e-01, -8.38107706e-01],
#        [ 2.70367388e-01, -2.87638347e-01],
#        [ 3.67578135e-01, -1.71750061e-01],
#        [-1.18475597e-01,  2.20395980e+00],
#        [-1.47942605e+00, -6.35303205e-01],
#        [-1.28500455e+00, -1.06988428e+00],
#        [-1.38221530e+00,  4.07691369e-01],
#        [-1.09058306e+00,  7.55356227e-01],
#        [-1.47942605e+00, -2.00722133e-01],
#        [ 9.50842613e-01, -1.06988428e+00],
#        [ 9.50842613e-01,  5.81523798e-01],
#        [ 3.67578135e-01,  9.87132798e-01],
#        [ 5.61999628e-01, -8.96051849e-01],
#        [-6.04529329e-01,  1.45068594e+00],
# ...

# %%
scaler.mean_
# Out:
# array([3.8218750e+01, 6.9928125e+04])

# %%
# we need to transform this above numpy array to dataframe
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %%
X_train_scaled
# Out:
#           Age  EstimatedSalary
# 0    1.922950         2.146016
# 1    2.020161         0.378719
# 2   -1.382215        -0.432499
# 3   -1.187794        -1.011940
# 4    1.922950        -0.925024
# ..        ...              ...
# 315  0.950843        -1.156800
# 316 -0.896162        -0.780164
# 317 -0.215686        -0.519415
# 318 -1.090583        -0.461471
# 319 -1.187794         1.392742
#
# [320 rows x 2 columns]

# %%
X_train_scaled.describe()           # returns the mathematical summary of the columns
# Out:
#               Age  EstimatedSalary
# count  320.000000     3.200000e+02
# mean     0.000000     1.110223e-17
# std      1.001566     1.001566e+00
# min     -1.965480    -1.591382e+00
# 25%     -0.798951    -7.801636e-01
# 50%     -0.021265    -1.240367e-02
# 75%      0.756421     5.235797e-01
# max      2.117372     2.319848e+00

# %%
X_train.describe()
# Out:
#              Age  EstimatedSalary
# count  320.00000       320.000000
# mean    38.21875     69928.125000
# std     10.30304     34570.057299
# min     18.00000     15000.000000
# 25%     30.00000     43000.000000
# 50%     38.00000     69500.000000
# 75%     46.00000     88000.000000
# max     60.00000    150000.000000

# %%
np.round(X_train.describe(), 2)
# Out:
#           Age  EstimatedSalary
# count  320.00           320.00
# mean    38.22         69928.12
# std     10.30         34570.06
# min     18.00         15000.00
# 25%     30.00         43000.00
# 50%     38.00         69500.00
# 75%     46.00         88000.00
# max     60.00        150000.00

# %%
np.round(X_test_scaled.describe(), 2)
# Out:
#          Age  EstimatedSalary
# count  80.00            80.00
# mean   -0.27            -0.03
# std     1.06             0.94
# min    -1.97            -1.59
# 25%    -1.09            -0.66
# 50%    -0.31             0.07
# 75%     0.37             0.47
# max     2.12             2.32

# %% [markdown]
# # 5. Effect of Scaling

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,5))
ax1.scatter(X_train['Age'], X_train['EstimatedSalary'])
ax1.set_title('Before Scaling')
ax2.scatter(X_train_scaled['Age'], X_train_scaled['EstimatedSalary'])
ax2.set_title('After Scaling')
plt.show()

# %% [markdown]
# #### Note: In above graphs data plots may appear similar but the scaling is different

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,5))

# before scaling
ax1.set_title('Before Scaling')
sns.kdeplot(X_train['Age'], ax=ax1, color='blue', label='Age')
sns.kdeplot(X_train['EstimatedSalary'], ax=ax1, color='red', label='Estimated Salary')
ax1.legend()

# after scaling
ax2.set_title('After Scaling')
sns.kdeplot(X_train_scaled['Age'], ax=ax2, color='blue', label='Age')
sns.kdeplot(X_train_scaled['EstimatedSalary'], ax=ax2, color='red', label='Estimated Salary')
ax2.legend()

plt.show()

# %% [markdown]
# # 6. Comparison of Distributions

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,5))

# before scaling
ax1.set_title('Age distribution before Scaling')
sns.kdeplot(X_train['Age'], ax=ax1, color='blue', label='Age')
ax1.legend()

# after scaling
ax2.set_title('Age Distribution after Scaling')
sns.kdeplot(X_train_scaled['Age'], ax=ax2, color='blue', label='Age')
ax2.legend()

plt.show()

# %% [markdown]
# #### Note: the above graphs may show similar but the scaling is different

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,5))

# before scaling
ax1.set_title('Estimade Salary distribution before Scaling')
sns.kdeplot(X_train['EstimatedSalary'], ax=ax1, color='red', label='Estimated Salary')
ax1.legend()

# after scaling
ax2.set_title('Estimated Salary Distribution after Scaling')
sns.kdeplot(X_train_scaled['EstimatedSalary'], ax=ax2, color='red', label='Estimated Salary')
ax2.legend()

plt.show()

# %% [markdown]
# #### Note: the above graphs may show similar but the scaling is different

# %% [markdown]
# # 7. Why Scaling is important?

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr_scaled = LogisticRegression()

# %%
lr.fit(X_train, y_train)
lr_scaled.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
lr.get_params()         # returns the parameters of the logistic Regression
# Out:
# {'C': 1.0,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': 0.0,
#  'max_iter': 100,
#  'n_jobs': None,
#  'penalty': 'deprecated',
#  'random_state': None,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
y_pred = lr.predict(X_test)
y_pred_scaled = lr_scaled.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score
print('Accuracy : ', accuracy_score(y_test, y_pred))
print('Scaled Accuracy : ', accuracy_score(y_test, y_pred_scaled))
# Out:
# Accuracy :  0.9125
# Scaled Accuracy :  0.925

# %% [markdown]
# # 8. Observe by Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt_scaled = DecisionTreeClassifier()

# %%
dt.fit(X_train, y_train)
dt_scaled.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(X_test)
y_pred_scaled = dt_scaled.predict(X_test_scaled)

# %%
print("Actual : ",accuracy_score(y_test, y_pred))
print("Scaled : ",accuracy_score(y_test, y_pred_scaled))
# Out:
# Actual :  0.9
# Scaled :  0.9125

# %%
df.describe()
# Out:
#               Age  EstimatedSalary   Purchased
# count  400.000000       400.000000  400.000000
# mean    37.655000     69742.500000    0.357500
# std     10.482877     34096.960282    0.479864
# min     18.000000     15000.000000    0.000000
# 25%     29.750000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     88000.000000    1.000000
# max     60.000000    150000.000000    1.000000

# %% [markdown]
# # 9. Effect of outliers

# %%
new_data = pd.DataFrame({'Age': [5, 90, 95], 'EstimatedSalary': [1000, 250000, 350000], 'Purchased': [0, 1, 1]})
df = pd.concat([df, new_data], ignore_index=True)
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 398   36            33000          0
# 399   49            36000          1
# 400    5             1000          0
# 401   90           250000          1
# 402   95           350000          1
#
# [403 rows x 3 columns]

# %%
plt.scatter(df['Age'], df['EstimatedSalary'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop('Purchased', axis=1), df['Purchased'], test_size=0.3, random_state=0)
X_train.shape, X_test.shape
# Out:
# ((282, 2), (121, 2))

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# fit the scaler to the train set, it will learn the parameters
scaler.fit(X_train)

# transform train and test sets
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

ax1.scatter(X_train['Age'], X_train['EstimatedSalary'])
ax1.set_title("Before Scaling")
ax2.scatter(X_train_scaled['Age'], X_train_scaled['EstimatedSalary'],color='red')
ax2.set_title("After Scaling")
plt.show()
