# %% [markdown]
# # 1. Import Libraries

# %%
import pandas as pd

# %% [markdown]
# # 2. Reading a CSV local file

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # 3. Install Pandas Profilling Report library

# %%
# !pip install ydata-profiling

# %% [markdown]
# # 4. Make report for the Titanic Dataset

# %%
from pandas_profiling import ProfileReport
titanic = ProfileReport(df)
titanic.to_file(output_file='titanic.html')
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_17816\4248758481.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # 5. Make Report for the Company Details Dataset

# %%
company_details = pd.read_csv('Company-details.csv')
company_details.head()
# Out:
#    Unnamed: 0 Company_Name  Ratings Rating_Count Salary Interview   Jobs
# 0           1          TCS      3.3         1.1L   9.8L     11.9k   2.7k
# 1           2          TCS      3.3         1.1L   9.8L     11.9k   2.7k
# 2           3    Accenture      3.7        71.9k   6.5L      9.2k  37.9k
# 3           4          TCS      3.3         1.1L   9.8L     11.9k   2.7k
# 4           5    Accenture      3.7        71.9k   6.5L      9.2k  37.9k

# %%
company_details = ProfileReport(company_details)
company_details.to_file(output_file='company_details.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # 6. Make Report for the Iris Dataset

# %%
iris = pd.read_csv('iris.csv')
iris.head()
# Out:
#    Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width species
# 0           0           5.1          3.5           1.4          0.2  setosa
# 1           1           4.9          3.0           1.4          0.2  setosa
# 2           2           4.7          3.2           1.3          0.2  setosa
# 3           3           4.6          3.1           1.5          0.2  setosa
# 4           4           5.0          3.6           1.4          0.2  setosa

# %%
iris = ProfileReport(iris)
iris.to_file(output_file='iris.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
